# %% [markdown]
# # 1. Menyertakan prefix dan suffix pada seluruh kolom `DataFrame`

# %% [markdown]
# ## Import modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.2.2
# 1.26.4

# %% [markdown]
# ## Persiapan `DataFrame`

# %%
n_rows = 5
n_cols = 5
cols = list("ABCDE")

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  2  9  1  1  7
# 1  2  8  9  7  2
# 2  5  3  6  9  6
# 3  1  9  6  1  9
# 4  8  6  5  7  2

# %% [markdown]
# ## Menyertakan prefix kolom

# %%
df.add_prefix("kolom_")
# Out:
#    kolom_A  kolom_B  kolom_C  kolom_D  kolom_E
# 0        2        9        1        1        7
# 1        2        8        9        7        2
# 2        5        3        6        9        6
# 3        1        9        6        1        9
# 4        8        6        5        7        2

# %% [markdown]
# ## Menyertakan suffix kolom

# %%
df.add_suffix("_field")
# Out:
#    A_field  B_field  C_field  D_field  E_field
# 0        2        9        1        1        7
# 1        2        8        9        7        2
# 2        5        3        6        9        6
# 3        1        9        6        1        9
# 4        8        6        5        7        2
